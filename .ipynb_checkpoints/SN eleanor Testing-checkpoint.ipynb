# %%
from IPython.display import Image

import warnings
warnings.filterwarnings('ignore')

import eleanor
import astroquery
import tess_stars2px
import numpy as np
from astropy import units as u

import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.time import Time
from astropy.time import TimeDelta
from astropy.timeseries import TimeSeries
from astropy.coordinates import SkyCoord
from astropy.visualization import time_support
time_support()
from astropy.visualization import quantity_support
quantity_support()
import lightkurve as lk
import pandas as pd
import time

import csv
import dis
import inspect
import os
import sys
from IPython.display import display_html

# %%
## Some general functions 
def mkdir(directory): 
    ##https://gist.github.com/keithweaver/562d3caa8650eefe7f84fa074e9ca949
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

def display_side_by_side(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

def unravel(list):
    return np.array([i for array in list for i in array])

savePNG = True
if savePNG:
    mpl.use("agg")
    plotExt = str('.png')
elif not savePNG:
    mpl.use("pgf")
    mpl.rcParams.update({
        "pgf.texsystem": "pdflatex",
        'font.family': 'serif',
        'text.usetex': True,
        'pgf.rcfonts': False,})
    plotExt = str('.pgf')

#%matplotlib inline
# %matplotlib notebook

# %%
coords = SkyCoord('13 23 29.02  +62 26 46.3',unit=(u.hourangle,u.deg))
sn2020bpi = eleanor.Source(coords=coords)
print('Found TIC {0} (Gaia {1}), with TESS magnitude {2}, RA {3}, and Dec {4}'
     .format(sn2020bpi.tic, sn2020bpi.gaia, sn2020bpi.tess_mag, sn2020bpi.coords[0], sn2020bpi.coords[1]))
#testcoord = SkyCoord(ra=sn2020bpi.coords[0],dec=sn2020bpi.coords[1],unit=(u.deg,u.deg))
data = eleanor.TargetData(sn2020bpi, height=15, width=15, do_psf=True, do_pca=True)
time.sleep(.1)
# Out:
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# Found TIC 367602816 (Gaia 1663967469745820672), with TESS magnitude 16.9863, RA 200.87091666666663, and Dec 62.446194444444444
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\eleanor\targetdata.py:836: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\eleanor\targetdata.py:836: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
# 100%|██████████████████████████████████████████████████████████████████████████████| 1248/1248 [00:13<00:00, 95.79it/s]

# %%
plt.figure(figsize=(15,5))

q = data.quality == 0

plt.plot(data.time[q], data.raw_flux[q]/np.nanmedian(data.raw_flux[q])+0.06, 'k')
plt.plot(data.time[q], data.corr_flux[q]/np.nanmedian(data.corr_flux[q]) + 0.03, 'r')
plt.plot(data.time[q], data.pca_flux[q]/np.nanmedian(data.pca_flux[q]), 'g')
plt.plot(data.time[q], data.psf_flux[q]/np.nanmedian(data.psf_flux[q]) - 0.02, 'b')
plt.ylabel('Normalized Flux')
plt.xlabel('Time [BJD - 2457000]')

plt.figure(figsize=(15,5))

plt.plot(data.time, data.flux_bkg, 'k', label='1D postcard', linewidth=3)
plt.plot(data.time, data.tpf_flux_bkg, 'r--', label='1D TPF', linewidth=2)
plt.ylabel('Normalized Flux')
plt.xlabel('Time [BJD - 2457000]')
plt.legend();

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))
ax1.imshow(data.tpf[0])
ax1.set_title('Target Pixel File')
ax2.imshow(data.bkg_tpf[0])
ax2.set_title('2D interpolated background');

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))
ax1.imshow(data.tpf[0])
ax1.set_title('Target Pixel File')
ax2.imshow(data.aperture)
ax2.set_title('Aperture');

# %%
# peakTime = lk2020.time[np.argmax(lk2020.flux)] ## btjd of peak
# #print(maxTime)
# peakTimeAstro = lk.utils.btjd_to_astropy_time(peakTime) ## astropy time product of peak
# peakTimeAstro.fits
# #time_support()
# #quantity_support()
# lk.utils.btjd_to_astropy_time(lk2020.time[0]).fits ## earliest date
# #dateTest = lk.utils.btjd_to_astropy_time(lk2020.time)
# dateTest = lk2020.astropy_time - Time("2020-02-14",format="iso").jd
# # with time_support() and quantity_support():
# plt.figure()
# plt.plot(dateTest, lk2020.flux,color=(0,.6,0.5))
# plt.xlabel("test")
# plt.ylabel("test")
# #plt.plot(lk2020.time, lk2020.flux)
# plt.locator_params(axis='x', nbins=10)
# #plt.axvline(x=Time(dateTest[0],format="isot"))
# plt.axvline(x=dateTest.jd[np.argmax(lk2020.flux)],color=(0.8,0.4,0),linestyle='dashed')
# plt.xticks(rotation=20)


# print(dateTest[0].jd)
# print(dateTest[-1])
# print(np.argmax(lk2020.flux))
# print(lk2020.time)
# print(dateTest.jd[np.argmax(lk2020.flux)])

# %% [markdown]
# Unfortunately, it seems the earliest date SN 2020bpi was observed by TESS was February 19th, five days after the estimated peak. However, on March 5th, there is a noticeable peak in the flux. Not sure what that is

# %%
def snStats(radec, peak, sector=None, tpfSize=15, 
            plot=False, savePlot=False, targetName=None, verbose=False):
    ## Uses eleanor to search for target SN in TESS field and identifies if peak is observed
    ## radec is taken as string in form 'hh mm ss +dd mm ss'
    ## peak is taken as string in form 'yyyy-mm-dd hh:mm:ss' or 'yyyy-mm-dd' (ie iso format)
    ## tpfSize is size of produced target pixel file in pixels (must be an odd number) 
    coords = SkyCoord(radec,unit=(u.hourangle,u.deg));
    if sector:
        target = eleanor.Source(coords=coords,sector=sector);
    elif not sector:
        target = eleanor.Source(coords=coords);
    data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False);
    ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
    time.sleep(0.10)
    peakTime = Time(peak, format='iso')
    obsStartTime = lk.utils.btjd_to_astropy_time(data.time)[0]
    obsEndTime = lk.utils.btjd_to_astropy_time(data.time)[-1]
    peakTimePres = obsStartTime.jd <= peakTime.jd <= obsEndTime.jd
    if not peakTimePres:
        timeDiff = np.around(peakTime.to_value('jd') - 
                             min([obsStartTime.to_value('jd'), obsEndTime.to_value('jd')], 
                                 key=lambda x:abs(x-peakTime.to_value('jd'))),2)
        print("Warning: provided peak is "+str(timeDiff)+" days outside of TESS time range")
        
    lc = data.to_lightkurve()
    daysFromPeak = lk.utils.btjd_to_astropy_time(lc.time) - peakTime.jd 
    obsPeak = Time(np.str(lc.time[np.argmax(lc.flux)]+2457000),format='jd')
    if verbose:
        print()
        print("Target Name: "+targetName if targetName else "")
        print("TESS Input Catalog (TIC) ID: "+str(target.tic))
        print("Located at: "+ticCoords.to_string('hmsdms'), end=" ")
        print("(exact target)" if ticCoords.ra==coords.ra and 
              ticCoords.dec==coords.dec else "(closest target)")
        print("TESS Sector: "+str(target.sector))
        print("Observation Start: "+obsStartTime.iso)
        print("Observation End: "+obsEndTime.iso)
        print("Observation Length: "+
              str(np.around(obsEndTime.to_value('jd') - obsStartTime.to_value('jd'),3))+' days')
        print("Peak Flux of "+str(np.around(np.max(lc.flux),3))+
              " e/s Observed on "+str(obsPeak.iso))
        print()
    if plot:
        fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15,4))
        ax1.imshow(data.tpf[0])
        ax1.set_title('Target Pixel File')
        ax2.imshow(data.bkg_tpf[0])
        ax2.set_title('2D interpolated background')
        ax3.imshow(data.aperture)
        ax3.set_title('Aperture')
        plotTitle = str(targetName+' (TIC '+
                        str(target.tic)+')') if targetName else str("Identified Target (TIC "
                                                                        +str(target.tic)+")")
        fig.suptitle(plotTitle)
        if savePlot:
            saveDir = str("./"+targetName+"/") if targetName else str("./TIC "+str(target.tic)+"/")
            mkdir(saveDir)
            fig.savefig(saveDir+"TPF"+plotExt, bbox_inches='tight')
        plt.show()
        
        plt.figure(figsize=(15,5))
        plt.plot(daysFromPeak, lc.flux/np.median(lc.flux), color=(0,0.6,0.5), label="Lightcurve")
        plt.axvline(x=daysFromPeak.jd[np.argmax(lc.flux)], color=(0,0,0),
                   linestyle='dotted', label='Max Flux: '+str(np.around(np.max(lc.flux),3))+' e/s')
        if peakTimePres:
            plt.axvline(x=0, color=(0.8,0.4,0), 
                        linestyle='dashed', label='Estimated Peak')
        plt.locator_params(axis='x', nbins=10)
        plt.xticks(rotation=20)
        plt.xlabel('Days From Estimated Peak')
        plt.ylabel('Normalized Flux')
        plt.legend()
        plt.title(plotTitle)
        if savePlot:
            saveDir = str("./"+targetName+"/") if targetName else str("./TIC "+str(target.tic)+"/")
            mkdir(saveDir)
            fig.savefig(saveDir+"lightcurve"+plotExt, bbox_inches='tight')
        plt.show()
        
    return [daysFromPeak, lc]

# %%
test = snStats(radec='13 23 29.02  +62 26 46.3',peak='2020-02-14', sector=21,
        plot=True,targetName='SN 2020bpi',verbose=True)
# Out:
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# Target Name: SN 2020bpi
# TESS Input Catalog (TIC) ID: 367602816
# Located at: 13h23m29.02s +62d26m46.3s (exact target)
# TESS Sector: 21
# Observation Start: 2020-01-21 22:48:43.352
# Observation End: 2020-02-18 06:19:27.486
# Observation Length: 27.313 days
# Peak Flux of 62.833 e/s Observed on 2020-02-05 11:19:14.037

# %%
snStats(radec='14 53 30.373 +17 17 20.97',peak='2020-03-09',
        plot=True,targetName='SN 2020dhj',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# SearchError                               Traceback (most recent call last)
# <ipython-input-8-c1a2a8729691> in <module>
#       1 snStats(radec='14 53 30.373 +17 17 20.97',peak='2020-03-09',
# ----> 2         plot=True,targetName='SN 2020dhj',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     240                 self.tess_mag = self.tess_mag[0]
#     241
# --> 242             self.locate_on_tess()
#     243             self.tesscut_size = 31
#     244
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in locate_on_tess(self)
#     277         # tess_stars2px returns array [-1] when star not observed yet
#     278         if len(sectors) < 1 or sectors[0] == np.array([-1]):
# --> 279             raise SearchError("Tess has not (yet) observed your target.")
#     280
#     281         else:
#
# SearchError: Tess has not (yet) observed your target.

# %%
snStats(radec='13 27 15.176 +32 02 00.74',peak='2020-03-19',
        plot=True,targetName='SN 2020ees',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-cbfe0a08472a> in <module>
#       1 snStats(radec='13 27 15.176 +32 02 00.74',peak='2020-03-19',
# ----> 2         plot=True,targetName='SN 2020ees',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     218                     self.contratio = 0.0
#     219                 if self.gaia is None:
# --> 220                     self.gaia = gaia_from_coords(self.coords)
#     221
#     222             elif self.gaia is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\mast.py in gaia_from_coords(coords)
#     184     gaiaPos = [gaia['MatchRA'], gaia['MatchDEC']]
#     185     sepGaia = crossmatch_distance(coords, gaiaPos)
# --> 186     return int(gaia[sepGaia==np.min(sepGaia)]['MatchID'].data[0])
#     187
#     188 def crossmatch_distance(pos, match):
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\units\quantity.py in __array_function__(self, function, types, args, kwargs)
#    1487         # implementation.
#    1488         if function in SUBCLASS_SAFE_FUNCTIONS:
# -> 1489             return super().__array_function__(function, types, args, kwargs)
#    1490
#    1491         elif function in FUNCTION_HELPERS:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2744     """
#    2745     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2746                           keepdims=keepdims, initial=initial, where=where)
#    2747
#    2748
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\units\quantity.py in __array_ufunc__(self, function, method, *inputs, **kwargs)
#     475
#     476         # Call our superclass's __array_ufunc__
# --> 477         result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#     478         # If unit is None, a plain array is expected (e.g., comparisons), which
#     479         # means we're done.
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
snStats(radec='15 34 33.036 +37 32 01.85',peak='2020-04-19',
        plot=True,targetName='SN 2020fxa',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8c77fc58c59a> in <module>
#       1 snStats(radec='15 34 33.036 +37 32 01.85',peak='2020-04-19',
# ----> 2         plot=True,targetName='SN 2020fxa',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     218                     self.contratio = 0.0
#     219                 if self.gaia is None:
# --> 220                     self.gaia = gaia_from_coords(self.coords)
#     221
#     222             elif self.gaia is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\mast.py in gaia_from_coords(coords)
#     184     gaiaPos = [gaia['MatchRA'], gaia['MatchDEC']]
#     185     sepGaia = crossmatch_distance(coords, gaiaPos)
# --> 186     return int(gaia[sepGaia==np.min(sepGaia)]['MatchID'].data[0])
#     187
#     188 def crossmatch_distance(pos, match):
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\units\quantity.py in __array_function__(self, function, types, args, kwargs)
#    1487         # implementation.
#    1488         if function in SUBCLASS_SAFE_FUNCTIONS:
# -> 1489             return super().__array_function__(function, types, args, kwargs)
#    1490
#    1491         elif function in FUNCTION_HELPERS:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2744     """
#    2745     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2746                           keepdims=keepdims, initial=initial, where=where)
#    2747
#    2748
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\units\quantity.py in __array_ufunc__(self, function, method, *inputs, **kwargs)
#     475
#     476         # Call our superclass's __array_ufunc__
# --> 477         result = super().__array_ufunc__(function, method, *arrays, **kwargs)
#     478         # If unit is None, a plain array is expected (e.g., comparisons), which
#     479         # means we're done.
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
snStats(radec='18 15 43.648 +58 12 54.81',peak='2020-05-16',
        plot=True,targetName='SN 2020jdo',verbose=True)
# Out:
# No eleanor postcard has been made for your target (yet). Using TessCut instead.
# Warning: provided peak is 59.03 days outside of TESS time range
# Target Name: SN 2020jdo
# TESS Input Catalog (TIC) ID: 10002089115
# Located at: 18h15m43.648s +58d12m54.81s (exact target)
# TESS Sector: 22
# Observation Start: 2020-02-19 19:44:39.603
# Observation End: 2020-03-17 23:15:08.973
# Observation Length: 27.146 days
# Peak Flux of 140.085 e/s Observed on 2020-02-19 19:44:39.603

# %%
snStats(radec='09 28 58.431 -14 48 19.76',peak='2020-05-22',
        plot=True,targetName='SN 2020jgl',verbose=True)
# Out:
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-1-2-cal-0608-0376_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-1-2-cal-0608-0376_tess_v2_bkg.fits with expected size 59621760. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-1-2-cal-0608-0376_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-1-2-cal-0608-0376_tess_v2_pc.fits with expected size 119327040. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-1-2-cal-0608-0376_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-1-2_tess_v2_pm.txt with expected size 180747. [astroquery.query]
# Warning: provided peak is 449.5 days outside of TESS time range
# Target Name: SN 2020jgl
# TESS Input Catalog (TIC) ID: 10002409466
# Located at: 09h28m58.431s -14d48m19.76s (exact target)
# TESS Sector: 8
# Observation Start: 2019-02-02 20:52:43.392
# Observation End: 2019-02-27 11:52:58.002
# Observation Length: 24.625 days
# Peak Flux of 4216.094 e/s Observed on 2019-02-02 23:22:43.628

# %%
snStats(radec='15 38 10.148 +04 46 50.39',peak='2020-06-05',
        plot=True,targetName='SN 2020kpx',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# SearchError                               Traceback (most recent call last)
# <ipython-input-13-29ac97346bd9> in <module>
#       1 snStats(radec='15 38 10.148 +04 46 50.39',peak='2020-06-05',
# ----> 2         plot=True,targetName='SN 2020kpx',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     240                 self.tess_mag = self.tess_mag[0]
#     241
# --> 242             self.locate_on_tess()
#     243             self.tesscut_size = 31
#     244
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in locate_on_tess(self)
#     277         # tess_stars2px returns array [-1] when star not observed yet
#     278         if len(sectors) < 1 or sectors[0] == np.array([-1]):
# --> 279             raise SearchError("Tess has not (yet) observed your target.")
#     280
#     281         else:
#
# SearchError: Tess has not (yet) observed your target.

# %%
snStats(radec='16 13 45.538 +22 55 14.36',peak='2020-06-09',
        plot=True,targetName='SN 2020kyx',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# SearchError                               Traceback (most recent call last)
# <ipython-input-14-0cca6aa3f9eb> in <module>
#       1 snStats(radec='16 13 45.538 +22 55 14.36',peak='2020-06-09',
# ----> 2         plot=True,targetName='SN 2020kyx',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     240                 self.tess_mag = self.tess_mag[0]
#     241
# --> 242             self.locate_on_tess()
#     243             self.tesscut_size = 31
#     244
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in locate_on_tess(self)
#     277         # tess_stars2px returns array [-1] when star not observed yet
#     278         if len(sectors) < 1 or sectors[0] == np.array([-1]):
# --> 279             raise SearchError("Tess has not (yet) observed your target.")
#     280
#     281         else:
#
# SearchError: Tess has not (yet) observed your target.

# %%
snStats(radec='14 37 59.666 +09 23 18.81',peak='2020-06-14',
        plot=True,targetName='SN 2020lil',verbose=True)
# Out:
# ---------------------------------------------------------------------------
# SearchError                               Traceback (most recent call last)
# <ipython-input-15-a999d13a8769> in <module>
#       1 snStats(radec='14 37 59.666 +09 23 18.81',peak='2020-06-14',
# ----> 2         plot=True,targetName='SN 2020lil',verbose=True)
#
# <ipython-input-6-91896b3c3d94> in snStats(radec, peak, tpfSize, plot, savePlot, targetName, verbose)
#       5     ## tpfSize is size of produced target pixel file in pixels (must be an odd number)
#       6     coords = SkyCoord(radec,unit=(u.hourangle,u.deg))
# ----> 7     target = eleanor.Source(coords=coords)
#       8     data = eleanor.TargetData(target, height=tpfSize, width=tpfSize, do_psf=False, do_pca=False)
#       9     ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in __init__(self, tic, gaia, coords, name, fn, sector, fn_dir, tc, local, post_dir, pm_dir, metadata_path)
#     240                 self.tess_mag = self.tess_mag[0]
#     241
# --> 242             self.locate_on_tess()
#     243             self.tesscut_size = 31
#     244
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\source.py in locate_on_tess(self)
#     277         # tess_stars2px returns array [-1] when star not observed yet
#     278         if len(sectors) < 1 or sectors[0] == np.array([-1]):
# --> 279             raise SearchError("Tess has not (yet) observed your target.")
#     280
#     281         else:
#
# SearchError: Tess has not (yet) observed your target.

# %%
asassn = snStats(radec='04 18 06.149 −63 36 56.68', sector=1, peak='2018-08-27 07:55:12.000',
        plot=True,targetName='ASASSN-18tb',verbose=True)
asassn[1].plot()
# Out:
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1_tess_v2_pm.txt with expected size 237847. [astroquery.query]
# Warning: provided peak is 4.67 days outside of TESS time range
#
# Target Name: ASASSN-18tb
# TESS Input Catalog (TIC) ID: 10000583619
# Located at: 04h18m06.149s -63d36m56.68s (exact target)
# TESS Sector: 1
# Observation Start: 2018-07-25 19:46:39.110
# Observation End: 2018-08-22 15:47:10.881
# Observation Length: 27.834 days
# Peak Flux of 494.291 e/s Observed on 2018-08-22 15:47:10.881

# %%
tCoord = SkyCoord('04 18 06.149 −63 36 56.68',unit=(u.hourangle,u.deg))
target = eleanor.multi_sectors(coords=tCoord,sectors='all')
#sec = [21,22]
#sec = 'all'
#target = eleanor.multi_sectors(coords=tCoord,sectors=sec)
# print(len(target))
#print(target[0].sector)
sectors= [target[sec].sector for sec in range(len(target))]
print(sectors)
# for i in range(len(target)):
#     print(target[i].sector)
#target.pm_dir = "C:\\Users\\Tyler\\.eleanor\\mastDownload\\HLSP\\"
data = []
for targ in target:
    for i in range(10):
        try:
            time.sleep(0.15)
            datum = eleanor.TargetData(targ, height=15, do_psf=False, do_pca=False)
            data.append(datum)
        except ValueError:
            print('fail number '+str(i))
            continue
        else:
            break
    else:
        print('didn\'t work')
for sector, datum in enumerate(data):
    q = datum.quality == 0
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,4))
    ax1.imshow(datum.tpf[q][0])
    ax1.set_title('Target Pixel File')
    ax2.imshow(datum.aperture)
    ax2.set_title('Aperture');
    plt.show()
for sector, datum in enumerate(data):
    q = datum.quality == 0
    plt.plot(datum.time[q],datum.corr_flux[q]/np.nanmedian(datum.corr_flux[q]))#,['k.', 'r.'])
#lk = data.to_lightcurve()
#lk.plot()
#ticCoords = SkyCoord(ra=target.coords[0],dec=target.coords[1],unit=(u.deg,u.deg))
# Out:
# Found star in Sector(s) 1 2 3 4 5 7 8 9 10 11 12 13
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_bkg.fits with expected size 78955200. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc.fits with expected size 158022720. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0001-4-1-cal-0706-0808_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0001-4-1_tess_v2_pm.txt with expected size 237847. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0002-4-1-cal-1490-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0002-4-1-cal-1490-0268_tess_v2_bkg.fits with expected size 76677120. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0002-4-1-cal-1490-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0002-4-1-cal-1490-0268_tess_v2_pc.fits with expected size 153463680. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0002-4-1-cal-1490-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0002-4-1_tess_v2_pm.txt with expected size 231901. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0003-4-2-cal-0216-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0003-4-2-cal-0216-0214_tess_v2_bkg.fits with expected size 79323840. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0003-4-2-cal-0216-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0003-4-2-cal-0216-0214_tess_v2_pc.fits with expected size 158760000. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0003-4-2-cal-0216-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0003-4-2_tess_v2_pm.txt with expected size 238620. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0004-4-2-cal-1098-0538_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0004-4-2-cal-1098-0538_tess_v2_bkg.fits with expected size 65286720. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0004-4-2-cal-1098-0538_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0004-4-2-cal-1098-0538_tess_v2_pc.fits with expected size 130665600. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0004-4-2-cal-1098-0538_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0004-4-2_tess_v2_pm.txt with expected size 197975. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0005-4-2-cal-1686-1186_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0005-4-2-cal-1686-1186_tess_v2_bkg.fits with expected size 73658880. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0005-4-2-cal-1686-1186_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0005-4-2-cal-1686-1186_tess_v2_pc.fits with expected size 147421440. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0005-4-2-cal-1686-1186_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0005-4-2_tess_v2_pm.txt with expected size 222610. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0007-4-3-cal-0412-1240_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0007-4-3-cal-0412-1240_tess_v2_bkg.fits with expected size 67317120. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0007-4-3-cal-0412-1240_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0007-4-3-cal-0412-1240_tess_v2_pc.fits with expected size 134729280. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0007-4-3-cal-0412-1240_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0007-4-3_tess_v2_pm.txt with expected size 202711. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-4-3-cal-1000-0592_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-4-3-cal-1000-0592_tess_v2_bkg.fits with expected size 59621760. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-4-3-cal-1000-0592_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-4-3-cal-1000-0592_tess_v2_pc.fits with expected size 119327040. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0008-4-3-cal-1000-0592_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0008-4-3_tess_v2_pm.txt with expected size 180359. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0009-4-3-cal-1784-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0009-4-3-cal-1784-0214_tess_v2_bkg.fits with expected size 71072640. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0009-4-3-cal-1784-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0009-4-3-cal-1784-0214_tess_v2_pc.fits with expected size 142246080. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0009-4-3-cal-1784-0214_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0009-4-3_tess_v2_pm.txt with expected size 214910. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0010-4-4-cal-0510-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0010-4-4-cal-0510-0268_tess_v2_bkg.fits with expected size 74583360. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0010-4-4-cal-0510-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0010-4-4-cal-0510-0268_tess_v2_pc.fits with expected size 149273280. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0010-4-4-cal-0510-0268_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0010-4-4_tess_v2_pm.txt with expected size 225506. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0011-4-4-cal-1294-0700_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0011-4-4-cal-1294-0700_tess_v2_bkg.fits with expected size 76861440. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0011-4-4-cal-1294-0700_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0011-4-4-cal-1294-0700_tess_v2_pc.fits with expected size 153832320. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0011-4-4-cal-1294-0700_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0011-4-4_tess_v2_pm.txt with expected size 233353. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0012-4-4-cal-1784-1456_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0012-4-4-cal-1784-1456_tess_v2_bkg.fits with expected size 79384320. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0012-4-4-cal-1784-1456_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0012-4-4-cal-1784-1456_tess_v2_pc.fits with expected size 158880960. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0012-4-4-cal-1784-1456_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0012-4-4_tess_v2_pm.txt with expected size 239463. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0013-4-1-cal-0216-1834_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0013-4-1-cal-0216-1834_tess_v2_bkg.fits with expected size 81293760. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0013-4-1-cal-0216-1834_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0013-4-1-cal-0216-1834_tess_v2_pc.fits with expected size 162702720. [astroquery.query]
# INFO: Found cached file C:\Users\Tyler\.eleanor/mastDownload\HLSP\hlsp_eleanor_tess_ffi_postcard-s0013-4-1-cal-0216-1834_tess_v2_pc\hlsp_eleanor_tess_ffi_postcard-s0013-4-1_tess_v2_pm.txt with expected size 245235. [astroquery.query]
# [1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 12, 13]
# fail number 0
# fail number 1
# fail number 2
# fail number 3
# fail number 4
# fail number 5
# fail number 6
# fail number 7
# fail number 8
# fail number 9
# didn't work
# fail number 0
# fail number 1
# fail number 2
# fail number 3
# fail number 4
# fail number 5
# fail number 6
# fail number 7
# fail number 8
# fail number 9
# didn't work
# fail number 0
# fail number 1
# fail number 2
# fail number 3
# fail number 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-07f76b58596f> in <module>
#      16         try:
#      17             time.sleep(0.15)
# ---> 18             datum = eleanor.TargetData(targ, height=15, do_psf=False, do_pca=False)
#      19             data.append(datum)
#      20         except ValueError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\targetdata.py in __init__(self, source, height, width, save_postcard, do_pca, do_psf, bkg_size, crowded_field, cal_cadences, try_load, regressors, language)
#     207                     self.pointing_model = None
#     208
# --> 209                 self.get_tpf_from_postcard(source.coords, source.postcard, height, width, bkg_size, save_postcard, source)
#     210                 self.set_quality()
#     211                 self.get_cbvs()
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\targetdata.py in get_tpf_from_postcard(self, pos, postcard, height, width, bkg_size, save_postcard, source)
#     354
#     355             self.bkg_tpf = post_bkg2d[:, y_low_lim:y_upp_lim, x_low_lim:x_upp_lim]
# --> 356             self.tpf_flux_bkg = self.bkg_subtraction() + post_bkg
#     357             self.tpf_err = post_err[: , y_low_lim:y_upp_lim, x_low_lim:x_upp_lim]
#     358             self.tpf_err[np.isnan(self.tpf_err)] = np.inf
#
# C:\ProgramData\Anaconda3\lib\site-packages\eleanor\targetdata.py in bkg_subtraction(self, scope, sigma)
#     504
#     505         for i in range(len(time)):
# --> 506             bkg_value = bkg.calc_background(flux[i])
#     507             tpf_flux_bkg.append(bkg_value)
#     508
#
# C:\ProgramData\Anaconda3\lib\site-packages\photutils\background\core.py in calc_background(self, data, axis)
#     278     def calc_background(self, data, axis=None):
#     279         if self.sigma_clip is not None:
# --> 280             data = self.sigma_clip(data, axis=axis)
#     281         return ((self.median_factor * _masked_median(data, axis=axis)) -
#     282                 (self.mean_factor * np.ma.mean(data, axis=axis)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\stats\sigma_clipping.py in __call__(self, data, axis, masked, return_bounds, copy)
#     466             return self._sigmaclip_noaxis(data, masked=masked,
#     467                                           return_bounds=return_bounds,
# --> 468                                           copy=copy)
#     469         else:
#     470             return self._sigmaclip_withaxis(data, axis=axis, masked=masked,
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\stats\sigma_clipping.py in _sigmaclip_noaxis(self, data, masked, return_bounds, copy)
#     300             iteration += 1
#     301             size = filtered_data.size
# --> 302             self._compute_bounds(filtered_data, axis=None)
#     303             filtered_data = filtered_data[(filtered_data >= self._min_value) &
#     304                                           (filtered_data <= self._max_value)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\stats\sigma_clipping.py in _compute_bounds(self, data, axis)
#     267         with warnings.catch_warnings():
#     268             warnings.simplefilter("ignore", category=RuntimeWarning)
# --> 269             self._max_value = self.cenfunc(data, axis=axis)
#     270             std = self.stdfunc(data, axis=axis)
#     271             self._min_value = self._max_value - (std * self.sigma_lower)
#
# C:\ProgramData\Anaconda3\lib\site-packages\astropy\stats\sigma_clipping.py in _nanmedian(array, axis)
#      69         return array.__array_wrap__(bottleneck.nanmedian(array, axis=axis))
#      70     else:
# ---> 71         return bottleneck.nanmedian(array, axis=axis)
#      72
#      73
#
# C:\ProgramData\Anaconda3\lib\site-packages\bottleneck\slow\reduce.py in nanmedian(a, axis)
#      73     with warnings.catch_warnings():
#      74         warnings.simplefilter("ignore")
# ---> 75         return np.nanmedian(a, axis=axis)
#      76
#      77
#
# <__array_function__ internals> in nanmedian(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in nanmedian(a, axis, out, overwrite_input, keepdims)
#    1113
#    1114     r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# -> 1115                                   overwrite_input=overwrite_input)
#    1116     if keepdims and keepdims is not np._NoValue:
#    1117         return r.reshape(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in _nanmedian(a, axis, out, overwrite_input)
#     982         part = a.ravel()
#     983         if out is None:
# --> 984             return _nanmedian1d(part, overwrite_input)
#     985         else:
#     986             out[...] = _nanmedian1d(part, overwrite_input)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in _nanmedian1d(arr1d, overwrite_input)
#     969         return np.nan
#     970
# --> 971     return np.median(arr1d, overwrite_input=overwrite_input)
#     972
#     973
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3500     """
#    3501     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3502                     overwrite_input=overwrite_input)
#    3503     if keepdims:
#    3504         return r.reshape(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _median(a, axis, out, overwrite_input)
#    3533             part = a
#    3534     else:
# -> 3535         part = partition(a, kth, axis=axis)
#    3536
#    3537     if part.shape == ():
#
# <__array_function__ internals> in partition(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in partition(a, kth, axis, kind, order)
#     743     else:
#     744         a = asanyarray(a).copy(order="K")
# --> 745     a.partition(kth, axis=axis, kind=kind, order=order)
#     746     return a
#     747
#
# KeyboardInterrupt:

# %%
# %%capture
tCoord = SkyCoord('04 18 06.149 −63 36 56.68',unit=(u.hourangle,u.deg));
target = eleanor.multi_sectors(coords=tCoord,sectors='all');
targets = []
sectors= [target[sec].sector for sec in range(len(target))];
#tsec = [print(sect) for sect in sectors]
#targets = [eleanor.Source(coords=tCoord,sector=sec) for sec in sectors]
#targets = eleanor.multi_sectors(coords=tCoord,sectors=sectors)
#data = [eleanor.TargetData(targ, height=15, do_psf=False, do_pca=False) for targ in targets]
# for sector, datum in enumerate(data):
#     q = datum.quality == 0
#     plt.plot(datum.time[q],datum.corr_flux[q]/np.nanmedian(datum.corr_flux[q]))#,['k.', 'r.'])
snTest = [snStats(radec='04 18 06.149 −63 36 56.68', peak='2018-08-27 07:55:12.000',
        plot=False,targetName='ASASSN-18tb',verbose=True)
          for sec in sectors
         ];
#snATest= np.array(snTest)
#plt.plot(snATest[:,0][1],snATest[:,1][1].flux/np.median(snATest[:,1][1].flux),color='red')

# %%
# %matplotlib inline
plt.figure()
snPTest = [plt.plot(snTest[chunk][0],
                    snTest[chunk][1].flux/np.median(snTest[chunk][1].flux))
           for chunk in range(len(snTest))
          ];
plt.show()

# %%
#snATest= np.array(snTest)
plt.plot(snTest[0][0],snTest[0][1].flux/np.median(snTest[0][1].flux),color='blue')
plt.plot(snTest[1][0],snTest[1][1].flux/np.median(snTest[1][1].flux),color='red')
plt.show()

# %%
#snStats(radec='04 18 06.149 −63 36 56.68', sector=1, peak='2018-08-27 07:55:12.000',
#        plot=True,targetName='ASASSN-18tb',verbose=True)
targ = SkyCoord('04 18 06.149 −63 36 56.68',unit=(u.hourangle,u.deg));
tpf = lk.search_tesscut(targ,sector=1).download(cutout_size=(31,31))
aper = tpf.create_threshold_mask()
raw_lc = tpf.to_lightcurve(aperture_mask=aper)
raw_lc.plot()
regressors = tpf.flux[:, ~aper]
plt.plot(regressors[:, :30]);
plt.show()

dm = lk.DesignMatrix(regressors, name='regressors')
dm = dm.pca(5)
plt.plot(tpf.time, dm.values + np.arange(5)*0.2, '.');
plt.show()

dm = dm.append_constant()
corrector = lk.RegressionCorrector(raw_lc)
corrected_lc = corrector.correct(dm)
ax = raw_lc.plot(label='Raw light curve')
corrected_lc.plot(ax=ax, label='Corrected light curve');
plt.show()

corrector.diagnose();
model = corrector.model_lc
model -= np.percentile(model.flux, 5)
model.plot();
plt.show()

# %%
corrected_lc = raw_lc - model
#ax = raw_lc.plot(label='Raw light curve',normalize=True)
ax = corrected_lc.scatter( label='Corrected light curve',normalize=True);

# %%
bkg = np.median(regressors, axis=1)
bkg -= np.percentile(bkg, 5)

npix = aper.sum()
median_subtracted_lc = raw_lc - npix * bkg

ax = median_subtracted_lc.plot(label='Median background subtraction',normalize=True)
corrected_lc.plot(ax=ax, label='RegressionCorrector',normalize=True);

# %%
s1 = eleanor.Source(gaia=4676041915767041280,sector=1);
s2 = eleanor.Source(gaia=4676043427595528448,sector=1);

d1 = eleanor.TargetData(s1)
d2 = eleanor.TargetData(s2)

# %%
d1k = d1.to_lightkurve().remove_outliers()
d2k = d2.to_lightkurve()
d1k.scatter(normalize=True,color='blue',label='s1')
d2k.scatter(normalize=True,color='red',label='s2')
plt.legend()
#correction = raw_lc - 0.5*(d1k + d2k)

# %%
d1p=d1k.to_pandas()
d2p=d2k.to_pandas()
d2p
# Out:
#             time        flux  flux_err
# 0    1325.324066  481.954498  1.105662
# 1    1325.344900  463.235788  1.115072
# 2    1325.365733  448.231551  1.126505
# 3    1325.386567  443.312057  1.140557
# 4    1325.407401  444.899685  1.155177
# ..           ...         ...       ...
# 989  1353.074433  455.796415  1.106444
# 990  1353.095266  456.625151  1.107154
# 991  1353.116100  461.964635  1.106554
# 992  1353.136933  474.619360  1.107238
# 993  1353.157767  494.291042  1.107681
#
# [994 rows x 3 columns]

# %%
def interpToMatch(item1,item2): 
    item1_indexed = item1.set_index('time')
    item2_indexed = item2.set_index('time')
    #display(item1_indexed)
    item1_length = len(item1_indexed.index)
    item2_length = len(item2_indexed.index)
    #display(item1_length)
    if item1_length >= item2_length:
        minun = item2_indexed.index.min()
        plusle = item2_indexed.index.max()
        numPoints = item2_length
    elif item1_length <= item2_length:
        minun = item1_indexed.index.min()
        plusle = item1_indexed.index.max()
        numPoints = item1_length
    #display(minun)
    #display(plusle)
    
    #numPoints = abs(plusle-minun)
    newIndex = np.linspace(minun,plusle-1,numPoints)
    #display(numPoints)
    #display(newIndex)
    
    item1_interp = pd.DataFrame(index=newIndex)
    item1_interp.index.name = item1_indexed.index.name
    item2_interp = pd.DataFrame(index=newIndex)
    item2_interp.index.name = item2_indexed.index.name

    for colname, col in item1_indexed.iteritems():
        item1_interp[colname] = np.interp(newIndex,item1_indexed.index,col)
    for colname, col in item2_indexed.iteritems():
        item2_interp[colname] = np.interp(newIndex,item2_indexed.index,col)
    item1_interp.reset_index(inplace=True)
    item2_interp.reset_index(inplace=True)
    
    return item1_interp, item2_interp

# %%
def interpToData(data, *args):
    interpArray = []
    
    data_indexed = data.set_index('time')
    data_length = len(data_indexed.index)
    minun = data_indexed.index.min()
    plusle = data_indexed.index.max()
    newIndex = np.linspace(minun,plusle-1,data_length)
    
    for arg in args:
        arg_indexed = arg.set_index('time')
        arg_interp = pd.DataFrame(index=newIndex)
        arg_interp.index.name = arg_indexed.index.name
        for colname, col in arg_indexed.iteritems():
            arg_interp[colname] = np.interp(newIndex,arg_indexed.index,col)
        arg_interp.reset_index(inplace=True)
        interpArray.append(arg_interp)
    return interpArray

# %%
snp = raw_lc.to_pandas()
#display_side_by_side(d1p, interpToData(d1p,d2p)[0])
d1pInterp, d2pInterp = interpToData(snp,d1p,d2p)
avgFlux = pd.DataFrame(index=snp.index)
avgFlux['time'] = 0.5 * (d1pInterp['time'] + d2pInterp['time'])
avgFlux['flux'] = 0.5 * (d1pInterp['flux'] + d2pInterp['flux']) 
avgFlux['flux_err'] = 0.5 * (d1pInterp['flux_err'] + d2pInterp['flux_err']) 
display_side_by_side(snp, d1pInterp, d2pInterp,avgFlux)
#interp1, interp2 = interpToData(d1p,d2p)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>flux</th>
#       <th>flux_err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1325.323975</td>
#       <td>101.025314</td>
#       <td>0.311233</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1325.344788</td>
#       <td>104.936996</td>
#       <td>0.315863</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1325.365662</td>
#       <td>109.992569</td>
#       <td>0.321745</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1325.386475</td>
#       <td>115.495407</td>
#       <td>0.328168</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1325.407288</td>
#       <td>122.584808</td>
#       <td>0.336096</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1325.428162</td>
#       <td>132.587128</td>
#       <td>0.347018</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1325.448975</td>
#       <td>143.549301</td>
#       <td>0.358239</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1325.469788</td>
#       <td>154.830078</td>
#       <td>0.369822</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1325.490662</td>
#       <td>167.464111</td>
#       <td>0.382361</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1325.511475</td>
#       <td>180.661057</td>
#       <td>0.394856</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1325.532288</td>
#       <td>192.158936</td>
#       <td>0.405766</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1325.553162</td>
#       <td>201.466736</td>
#       <td>0.414237</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1325.573975</td>
#       <td>209.294281</td>
#       <td>0.421330</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1325.594788</td>
#       <td>214.070938</td>
#       <td>0.425650</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1325.615662</td>
#       <td>217.013824</td>
#       <td>0.428212</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1325.636475</td>
#       <td>215.736420</td>
#       <td>0.427076</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1325.657288</td>
#       <td>213.349319</td>
#       <td>0.425104</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1325.678162</td>
#       <td>212.982117</td>
#       <td>0.424373</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1325.698975</td>
#       <td>210.865112</td>
#       <td>0.422855</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1325.719788</td>
#       <td>211.389145</td>
#       <td>0.423239</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1325.740662</td>
#       <td>212.687317</td>
#       <td>0.424649</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1325.761475</td>
#       <td>215.125778</td>
#       <td>0.426475</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1325.782288</td>
#       <td>218.054321</td>
#       <td>0.429138</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1325.803162</td>
#       <td>220.116974</td>
#       <td>0.430871</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1325.823975</td>
#       <td>220.197327</td>
#       <td>0.431098</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1325.844788</td>
#       <td>219.250946</td>
#       <td>0.430248</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1325.865662</td>
#       <td>216.572342</td>
#       <td>0.428004</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1325.886475</td>
#       <td>211.025909</td>
#       <td>0.422992</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1325.907288</td>
#       <td>206.943039</td>
#       <td>0.419243</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1325.928162</td>
#       <td>203.380600</td>
#       <td>0.416136</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1325.948975</td>
#       <td>200.441895</td>
#       <td>0.413687</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1325.969788</td>
#       <td>197.668350</td>
#       <td>0.411142</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1325.990662</td>
#       <td>197.177292</td>
#       <td>0.410560</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1326.011475</td>
#       <td>198.518997</td>
#       <td>0.411884</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>1326.032288</td>
#       <td>200.005829</td>
#       <td>0.413222</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>1326.053162</td>
#       <td>198.837616</td>
#       <td>0.412102</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>1326.074036</td>
#       <td>198.324219</td>
#       <td>0.411702</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>1326.094849</td>
#       <td>197.547882</td>
#       <td>0.411159</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>1326.115662</td>
#       <td>196.254379</td>
#       <td>0.410013</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>1326.136536</td>
#       <td>195.941269</td>
#       <td>0.409491</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>1326.157349</td>
#       <td>194.229904</td>
#       <td>0.408260</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>1326.178162</td>
#       <td>193.174713</td>
#       <td>0.407117</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>1326.199036</td>
#       <td>191.979630</td>
#       <td>0.406085</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>1326.219849</td>
#       <td>190.118607</td>
#       <td>0.404247</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>1326.240662</td>
#       <td>188.547867</td>
#       <td>0.402681</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>1326.261536</td>
#       <td>187.429367</td>
#       <td>0.401839</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>1326.282349</td>
#       <td>186.044388</td>
#       <td>0.400686</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>1326.303162</td>
#       <td>185.103119</td>
#       <td>0.399797</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>1326.324036</td>
#       <td>184.169479</td>
#       <td>0.398557</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>1326.344849</td>
#       <td>184.258316</td>
#       <td>0.398720</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>1326.365662</td>
#       <td>183.682434</td>
#       <td>0.398427</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>1326.386536</td>
#       <td>184.575729</td>
#       <td>0.398989</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>1326.407349</td>
#       <td>184.142319</td>
#       <td>0.398861</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>1326.428162</td>
#       <td>184.896454</td>
#       <td>0.399410</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>1326.449036</td>
#       <td>185.165329</td>
#       <td>0.399666</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>1326.469849</td>
#       <td>184.634033</td>
#       <td>0.399244</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>1326.490662</td>
#       <td>185.149170</td>
#       <td>0.399518</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>1326.511536</td>
#       <td>184.991379</td>
#       <td>0.399536</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>1326.532349</td>
#       <td>186.302551</td>
#       <td>0.400764</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>1326.553162</td>
#       <td>186.161636</td>
#       <td>0.400601</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>1326.574036</td>
#       <td>186.480713</td>
#       <td>0.400867</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>1326.594849</td>
#       <td>186.572739</td>
#       <td>0.401248</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>1326.615662</td>
#       <td>187.056549</td>
#       <td>0.401647</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>1326.636536</td>
#       <td>185.496017</td>
#       <td>0.400242</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>1326.657349</td>
#       <td>184.624191</td>
#       <td>0.399175</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>1326.678162</td>
#       <td>183.095856</td>
#       <td>0.397836</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>1326.699036</td>
#       <td>180.818192</td>
#       <td>0.395823</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>1326.719849</td>
#       <td>179.122375</td>
#       <td>0.394140</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>1326

# %%
ax = d2p.plot(x='time',y='flux',color='red',label='original',kind='scatter')
d2pInterp.plot(x='time',y='flux',color='blue',label='interpolated',alpha=0.3,kind='scatter',ax=ax)
plt.legend()

# %%
# targ = SkyCoord('04 18 06.149 −63 36 56.68',unit=(u.hourangle,u.deg));
# tpf = lk.search_tesscut(targ,sector=1).download(cutout_size=(31,31))
# aper = tpf.create_threshold_mask()
# raw_lc = tpf.to_lightcurve(aperture_mask=aper)
# Out:
#              time        flux  flux_err
# 0     1325.323975  101.025314  0.311233
# 1     1325.344788  104.936996  0.315863
# 2     1325.365662  109.992569  0.321745
# 3     1325.386475  115.495407  0.328168
# 4     1325.407288  122.584808  0.336096
# ...           ...         ...       ...
# 1262  1353.074280  106.083939  0.316820
# 1263  1353.095093  106.565002  0.317166
# 1264  1353.115906  106.712494  0.317378
# 1265  1353.136780  107.349052  0.318124
# 1266  1353.157593  107.577805  0.318579
#
# [1267 rows x 3 columns]
